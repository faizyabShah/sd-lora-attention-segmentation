# %%
# !pip install -q diffusers[training]==0.36.0 transformers accelerate peft bitsandbytes datasets

import torch
print(f"GPU: {torch.cuda.get_device_name(0)}")
print(f"VRAM: {torch.cuda.get_device_properties(0).total_memory / 1e9:.1f} GB")
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.7/60.7 MB 33.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 162.1/162.1 kB 12.8 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# bigframes 2.35.0 requires google-cloud-bigquery-storage<3.0.0,>=2.30.0, which is not installed.
# google-adk 1.25.1 requires google-cloud-bigquery-storage>=2.0.0, which is not installed.
# a2a-sdk 0.3.25 requires protobuf>=5.29.5, but you have protobuf 3.20.3 which is incompatible.
# onnx 1.20.1 requires protobuf>=4.25.1, but you have protobuf 3.20.3 which is incompatible.
# grain 0.2.15 requires protobuf>=5.28.3, but you have protobuf 3.20.3 which is incompatible.
# tensorflow-metadata 1.17.3 requires protobuf>=4.25.2; python_version >= "3.11", but you have protobuf 3.20.3 which is incompatible.
# ydf 0.15.0 requires protobuf<7.0.0,>=5.29.1, but you have protobuf 3.20.3 which is incompatible.
# google-api-core 2.30.0 requires protobuf<7.0.0,>=4.25.8, but you have protobuf 3.20.3 which is incompatible.
# opentelemetry-proto 1.38.0 requires protobuf<7.0,>=5.0, but you have protobuf 3.20.3 which is incompatible.
# grpcio-status 1.71.2 requires protobuf<6.0dev,>=5.26.1, but you have protobuf 3.20.3 which is incompatible.
# GPU: Tesla T4
# VRAM: 15.6 GB

# %% [markdown]
# Add the cityscapes dataset, florence2 generated captions, and the stable diffusion dataset (i put it as a dataset on kaggle because pulling it from the hugging face repository during script execution was very slow, maybe due to kaggle server limitations idk) as input for this kaggle notebook

# %% [markdown]
# Check if the stable diffusion dataset has the right files

# %%
import os

print("=== All inputs ===")
for item in os.listdir("/kaggle/input/"):
    print(f"  {item}")

# # Check SD 1.5 model structure
# print("\n=== SD 1.5 model files ===")
# sd_path = None
# for root, dirs, files in os.walk("/kaggle/input/"):
#     for f in files:
#         if f == "model_index.json":
#             sd_path = root
#             break
#     if sd_path:
#         break

# if sd_path:
#     print(f"Model root: {sd_path}")
#     for f in ["unet/diffusion_pytorch_model.safetensors", 
#               "text_encoder/model.safetensors",
#               "vae/diffusion_pytorch_model.safetensors",
#               "model_index.json"]:
#         full = os.path.join(sd_path, f)
#         if os.path.exists(full):
#             size = os.path.getsize(full) / 1e6
#             print(f"  ✓ {size:8.0f} MB  {f}")
#         else:
#             print(f"  ✗ MISSING     {f}")
# else:
#     print("model_index.json not found — check dataset structure")
# Out:
# === All inputs ===
#   datasets

# %% [markdown]
# Check if the florence captions dataset and cityscapes dataset have the right files

# %%
import os

print("=== Available input datasets ===")
for item in os.listdir("/kaggle/input/datasets/narmeensabahsiddiqui"):
    print(f"  {item}")

# Check the captions dataset structure
captions_path = "/kaggle/input/datasets/narmeensabahsiddiqui/florence2-detailedcaptions-cityscapes"
print("=== Captions dataset ===")
for item in os.listdir(captions_path):
    print(f"  {item}")

# Check the images dataset structure
images_path = "/kaggle/input/datasets/narmeensabahsiddiqui/cityscapes-leftimg8bit-traintestval"
print("\n=== Images dataset ===")
for item in os.listdir(images_path):
    print(f"  {item}")
    subpath = os.path.join(images_path, item)
    if os.path.isdir(subpath):
        for sub in os.listdir(subpath)[:5]:
            print(f"    {sub}")
# Out:
# === Available input datasets ===
#   florence2-detailedcaptions-cityscapes
#   cityscapes-leftimg8bit-traintestval
# === Captions dataset ===
#   metadata.jsonl
#   captions.json
#   __huggingface_repos__.json
#
# === Images dataset ===
#   leftImg8bit
#     val
#     test
#     train
#   README
#   license.txt

# %% [markdown]
# Assembling the dataset to be used by the hugging face's prebuilt train_text_to_image_lora training script

# %%
import os
import json
import shutil

IMAGES_ROOT = "/kaggle/input/datasets/narmeensabahsiddiqui/cityscapes-leftimg8bit-traintestval/leftImg8bit"
CAPTIONS_FILE = "/kaggle/input/datasets/narmeensabahsiddiqui/florence2-detailedcaptions-cityscapes/metadata.jsonl"
TRAIN_DIR = "/kaggle/working/lora325000_dataset"

# Create the training directory
os.makedirs(TRAIN_DIR, exist_ok=True)

# Symlink the train folder so images are accessible at lora_dataset/train/city/image.png
try:
    os.symlink(os.path.join(IMAGES_ROOT, "train"), os.path.join(TRAIN_DIR, "train"))
    os.symlink(os.path.join(IMAGES_ROOT, "test"), os.path.join(TRAIN_DIR, "test"))
    os.symlink(os.path.join(IMAGES_ROOT, "val"), os.path.join(TRAIN_DIR, "val"))
except:
    print("Symlink did not work")
    pass
# Copy metadata.jsonl into the training directory
shutil.copy(CAPTIONS_FILE, os.path.join(TRAIN_DIR, "metadata.jsonl"))

# Verify: check that a few image paths from metadata.jsonl actually resolve
with open(os.path.join(TRAIN_DIR, "metadata.jsonl"), "r") as f:
    first_entry = json.loads(f.readline())

test_path = os.path.join(TRAIN_DIR, first_entry["file_name"])
print(f"First entry file_name: {first_entry['file_name']}")
print(f"Full resolved path:    {test_path}")
print(f"File exists: {os.path.exists(test_path)}")
print(f"Caption: {first_entry['text'][:100]}...")

# Count total entries
with open(os.path.join(TRAIN_DIR, "metadata.jsonl"), "r") as f:
    total = sum(1 for _ in f)
print(f"\nTotal image-caption pairs: {total}")
# Out:
# First entry file_name: train/aachen/aachen_000000_000019_leftImg8bit.png
# Full resolved path:    /kaggle/working/lora325000_dataset/train/aachen/aachen_000000_000019_leftImg8bit.png
# File exists: True
# Caption: A car driving down a street lined with tall buildings, trees, light poles, and sign boards. The sky ...
#
# Total image-caption pairs: 5000

# %% [markdown]
# Download the training script "train_text_to_image_lora.py" from diffusers library on hugging face's github

# %%
# Download the training script that matches our installed diffusers version (0.36.0)
import os
if not os.path.exists('/kaggle/working/train_text_to_image_lora.py'):
    # !wget -q https://raw.githubusercontent.com/huggingface/diffusers/v0.36.0/examples/text_to_image/train_text_to_image_lora.py -O /kaggle/working/train_text_to_image_lora.py
    print("Script downloaded")
    print(f"Script exists: {os.path.exists('/kaggle/working/train_text_to_image_lora.py')}")
else:
    print("Script exists")

# Verify it doesn't have the version check issue
# !head -70 /kaggle/working/train_text_to_image_lora.py | grep "check_min_version"
# Out:
# Script downloaded
# Script exists: True
#     check_min_version,
# check_min_version("0.36.0")

# %% [markdown]
# patch the code to convert all the trainable params to float32. This is a limitation of the new version of accelerate library that is present on this kaggle environment

# %%
with open("/kaggle/working/train_text_to_image_lora.py", "r") as f:
    lines = f.readlines()

with open("/kaggle/working/train_text_to_image_lora.py", "w") as f:
    for line in lines:
        f.write(line)
        if "unet.add_adapter(unet_lora_config)" in line:
            f.write("    # Fix: cast LoRA params to float32 for mixed precision training\n")
            f.write("    for param in unet.parameters():\n")
            f.write("        if param.requires_grad:\n")
            f.write("            param.data = param.data.to(torch.float32)\n")

# Verify
with open("/kaggle/working/train_text_to_image_lora.py", "r") as f:
    content = f.read()
print("Patched:" if "param.data.to(torch.float32)" in content else "PATCH FAILED")
# Out:
# Patched:

# %%
# SD_MODEL_PATH = "/kaggle/input/datasets/narmeensabahsiddiqui/sd15-diffusers"

# !accelerate launch --multi_gpu --num_processes=2 --mixed_precision="fp16" \
  /kaggle/working/train_text_to_image_lora.py \
  --pretrained_model_name_or_path="stable-diffusion-v1-5/stable-diffusion-v1-5" \
  --train_data_dir="/kaggle/working/lora325000_dataset" \
  --caption_column="text" \
  --resolution=512 \
  --center_crop \
  --train_batch_size=1 \
  --gradient_accumulation_steps=4 \
  --max_train_steps=5000 \
  --learning_rate=1e-4 \
  --max_grad_norm=1.0 \
  --lr_scheduler="cosine" \
  --lr_warmup_steps=200 \
  --snr_gamma=5.0 \
  --rank=32 \
  --output_dir="/kaggle/working/cityscapes-lora325000" \
  --checkpointing_steps=400 \
  --seed=42 \
  --logging_dir="/kaggle/working/logs-325000" \
  --report_to="tensorboard"
# Out:
# The following values were not passed to `accelerate launch` and had defaults used instead:
# 	`--num_machines` was set to a value of `1`
# 	`--dynamo_backend` was set to a value of `'no'`
# To avoid this warning pass in values for each of the problematic parameters or run `accelerate config`.
# Flax classes are deprecated and will be removed in Diffusers v1.0.0. We recommend migrating to PyTorch classes or pinning your version of Diffusers.
# Flax classes are deprecated and will be removed in Diffusers v1.0.0. We recommend migrating to PyTorch classes or pinning your version of Diffusers.
# Flax classes are deprecated and will be removed in Diffusers v1.0.0. We recommend migrating to PyTorch classes or pinning your version of Diffusers.
# Flax classes are deprecated and will be removed in Diffusers v1.0.0. We recommend migrating to PyTorch classes or pinning your version of Diffusers.
# INFO:__main__:Distributed environment: DistributedType.MULTI_GPU  Backend: nccl
# Num processes: 2
# Process index: 0
# Local process index: 0
# Device: cuda:0
#
# Mixed precision type: fp16
#
# INFO:__main__:Distributed environment: DistributedType.MULTI_GPU  Backend: nccl
# Num processes: 2
# Process index: 1
# Local process index: 1
# Device: cuda:1
#
# Mixed precision type: fp16
#
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_validators.py:202: UserWarning: The `local_dir_use_symlinks` argument is deprecated and ignored in `hf_hub_download`. Downloading to a local directory does not use symlinks anymore.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_validators.py:202: UserWarning: The `local_dir_use_symlinks` argument is deprecated and ignored in `hf_hub_download`. Downloading to a local directory does not use symlinks anymore.
#   warnings.warn(
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/stable-diffusion-v1-5/stable-diffusion-v1-5/resolve/main/scheduler/scheduler_config.json "HTTP/1.1 307 Temporary Redirect"
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/stable-diffusion-v1-5/stable-diffusion-v1-5/resolve/main/scheduler/scheduler_config.json "HTTP/1.1 307 Temporary Redirect"
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/stable-diffusion-v1-5/stable-diffusion-v1-5/451f4fe16113bff5a5d2269ed5ad43b0592e9a14/scheduler%2Fscheduler_config.json "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/stable-diffusion-v1-5/stable-diffusion-v1-5/451f4fe16113bff5a5d2269ed5ad43b0592e9a14/scheduler%2Fscheduler_config.json "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://huggingface.co/api/resolve-cache/models/stable-diffusion-v1-5/stable-diffusion-v1-5/451f4fe16113bff5a5d2269ed5ad43b0592e9a14/scheduler%2Fscheduler_config.json "HTTP/1.1 200 OK"
# scheduler_config.json: 100%|███████████████████| 308/308 [00:00<00:00, 1.47MB/s]
# {'clip_sample_range', 'dynamic_thresholding_ratio', 'prediction_type', 'timestep_spacing', 'variance_type', 'rescale_betas_zero_snr', 'thresholding', 'sample_max_value'} was not found in config. Values will be initialized to default values.
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/stable-diffusion-v1-5/stable-diffusion-v1-5/resolve/main/tokenizer/tokenizer_config.json "HTTP/1.1 307 Temporary Redirect"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/stable-diffusion-v1-5/stable-diffusion-v1-5/resolve/main/tokenizer/tokenizer_config.json "HTTP/1.1 307 Temporary Redirect"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/stable-diffusion-v1-5/stable-diffusion-v1-5/451f4fe16113bff5a5d2269ed5ad43b0592e9a14/tokenizer%2Ftokenizer_config.json "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/stable-diffusion-v1-5/stable-diffusion-v1-5/451f4fe16113bff5a5d2269ed5ad43b0592e9a14/tokenizer%2Ftokenizer_config.json "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://huggingface.co/api/resolve-cache/models/stable-diffusion-v1-5/stable-diffusion-v1-5/451f4fe16113bff5a5d2269ed5ad43b0592e9a14/tokenizer%2Ftokenizer_config.json "HTTP/1.1 200 OK"
# tokenizer_config.json: 100%|███████████████████| 806/806 [00:00<00:00, 3.61MB/s]
# INFO:httpx:HTTP Request: GET https://huggingface.co/api/models/stable-diffusion-v1-5/stable-diffusion-v1-5/tree/main/additional_chat_templates?recursive=false&expand=false "HTTP/1.1 404 Not Found"
# INFO:httpx:HTTP Request: GET https://huggingface.co/api/models/stable-diffusion-v1-5/stable-diffusion-v1-5/tree/main/additional_chat_templates?recursive=false&expand=false "HTTP/1.1 404 Not Found"
# INFO:httpx:HTTP Request: GET https://huggingface.co/api/models/stable-diffusion-v1-5/stable-diffusion-v1-5/tree/main?recursive=true&expand=false "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://huggingface.co/api/models/stable-diffusion-v1-5/stable-diffusion-v1-5/tree/main?recursive=true&expand=false "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/stable-diffusion-v1-5/stable-diffusion-v1-5/resolve/main/tokenizer/vocab.json "HTTP/1.1 307 Temporary Redirect"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/stable-diffusion-v1-5/stable-diffusion-v1-5/451f4fe16113bff5a5d2269ed5ad43b0592e9a14/tokenizer%2Fvocab.json "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://huggingface.co/api/resolve-cache/models/stable-diffusion-v1-5/stable-diffusion-v1-5/451f4fe16113bff5a5d2269ed5ad43b0592e9a14/tokenizer%2Fvocab.json "HTTP/1.1 200 OK"
# vocab.json: 0.00B [00:00, ?B/s]INFO:httpx:HTTP Request: HEAD https://huggingface.co/stable-diffusion-v1-5/stable-diffusion-v1-5/resolve/main/tokenizer/vocab.json "HTTP/1.1 307 Temporary Redirect"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/stable-diffusion-v1-5/stable-diffusion-v1-5/451f4fe16113bff5a5d2269ed5ad43b0592e9a14/tokenizer%2Fvocab.json "HTTP/1.1 200 OK"
# vocab.json: 1.06MB [00:00, 31.7MB/s]
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/stable-diffusion-v1-5/stable-diffusion-v1-5/resolve/main/tokenizer/merges.txt "HTTP/1.1 307 Temporary Redirect"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/stable-diffusion-v1-5/stable-diffusion-v1-5/451f4fe16113bff5a5d2269ed5ad43b0592e9a14/tokenizer%2Fmerges.txt "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://huggingface.co/api/resolve-cache/models/stable-diffusion-v1-5/stable-diffusion-v1-5/451f4fe16113bff5a5d2269ed5ad43b0592e9a14/tokenizer%2Fmerges.txt "HTTP/1.1 200 OK"
# merges.txt: 0.00B [00:00, ?B/s]INFO:httpx:HTTP Request: HEAD https://huggingface.co/stable-diffusion-v1-5/stable-diffusion-v1-5/resolve/main/tokenizer/merges.txt "HTTP/1.1 307 Temporary Redirect"
# merges.txt: 525kB [00:00, 105MB/s]
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/stable-diffusion-v1-5/stable-diffusion-v1-5/451f4fe16113bff5a5d2269ed5ad43b0592e9a14/tokenizer%2Fmerges.txt "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/stable-diffusion-v1-5/stable-diffusion-v1-5/resolve/main/tokenizer/tokenizer.json "HTTP/1.1 404 Not Found"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/stable-diffusion-v1-5/stable-diffusion-v1-5/resolve/main/tokenizer/tokenizer.json "HTTP/1.1 404 Not Found"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/stable-diffusion-v1-5/stable-diffusion-v1-5/resolve/main/tokenizer/added_tokens.json "HTTP/1.1 404 Not Found"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/stable-diffusion-v1-5/stable-diffusion-v1-5/resolve/main/tokenizer/added_tokens.json "HTTP/1.1 404 Not Found"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/stable-diffusion-v1-5/stable-diffusion-v1-5/resolve/main/tokenizer/special_tokens_map.json "HTTP/1.1 307 Temporary Redirect"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/stable-diffusion-v1-5/stable-diffusion-v1-5/451f4fe16113bff5a5d2269ed5ad43b0592e9a14/tokenizer%2Fspecial_tokens_map.json "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/stable-diffusion-v1-5/stable-diffusion-v1-5/resolve/main/tokenizer/special_tokens_map.json "HTTP/1.1 307 Temporary Redirect"
# INFO:httpx:HTTP Request: GET https://huggingface.co/api/resolve-cache/models/stable-diffusion-v1-5/stable-diffusion-v1-5/451f4fe16113bff5a5d2269ed5ad43b0592e9a14/tokenizer%2Fspecial_tokens_map.json "HTTP/1.1 200 OK"
# special_tokens_map.json: 100%|█████████████████| 472/472 [00:00<00:00, 2.68MB/s]
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/stable-diffusion-v1-5/stable-diffusion-v1-5/451f4fe16113bff5a5d2269ed5ad43b0592e9a14/tokenizer%2Fspecial_tokens_map.json "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/stable-diffusion-v1-5/stable-diffusion-v1-5/resolve/main/tokenizer/chat_template.jinja "HTTP/1.1 404 Not Found"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/stable-diffusion-v1-5/stable-diffusion-v1-5/resolve/main/tokenizer/chat_template.jinja "HTTP/1.1 404 Not Found"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/stable-diffusion-v1-5/stable-diffusion-v1-5/resolve/main/text_encoder/config.json "HTTP/1.1 307 Temporary Redirect"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/stable-diffusion-v1-5/stable-diffusion-v1-5/resolve/main/text_encoder/config.json "HTTP/1.1 307 Temporary Redirect"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/stable-diffusion-v1-5/stable-diffusion-v1-5/451f4fe16113bff5a5d2269ed5ad43b0592e9a14/text_encoder%2Fconfig.json "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/stable-diffusion-v1-5/stable-diffusion-v1-5/451f4fe16113bff5a5d2269ed5ad43b0592e9a14/text_encoder%2Fconfig.json "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://huggingface.co/api/resolve-cache/models/stable-diffusion-v1-5/stable-diffusion-v1-5/451f4fe16113bff5a5d2269ed5ad43b0592e9a14/text_encoder%2Fconfig.json "HTTP/1.1 200 OK"
# config.json: 100%|█████████████████████████████| 617/617 [00:00<00:00, 1.97MB/s]
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/stable-diffusion-v1-5/stable-diffusion-v1-5/resolve/main/text_encoder/adapter_config.json "HTTP/1.1 404 Not Found"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/stable-diffusion-v1-5/stable-diffusion-v1-5/resolve/main/text_encoder/adapter_config.json "HTTP/1.1 404 Not Found"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/stable-diffusion-v1-5/stable-diffusion-v1-5/resolve/main/text_encoder/config.json "HTTP/1.1 307 Temporary Redirect"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/stable-diffusion-v1-5/stable-diffusion-v1-5/451f4fe16113bff5a5d2269ed5ad43b0592e9a14/text_encoder%2Fconfig.json "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/stable-diffusion-v1-5/stable-diffusion-v1-5/resolve/main/text_encoder/config.json "HTTP/1.1 307 Temporary Redirect"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/stable-diffusion-v1-5/stable-diffusion-v1-5/451f4fe16113bff5a5d2269ed5ad43b0592e9a14/text_encoder%2Fconfig.json "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/stable-diffusion-v1-5/stable-diffusion-v1-5/resolve/main/text_encoder/model.safetensors "HTTP/1.1 302 Found"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/stable-diffusion-v1-5/stable-diffusion-v1-5/resolve/main/text_encoder/model.safetensors "HTTP/1.1 302 Found"
# INFO:httpx:HTTP Request: GET https://huggingface.co/api/models/stable-diffusion-v1-5/stable-diffusion-v1-5/xet-read-token/451f4fe16113bff5a5d2269ed5ad43b0592e9a14 "HTTP/1.1 200 OK"
# text_encoder/model.safetensors:  95%|████████▌| 470M/492M [00:02<00:00, 167MB/s]
# Loading weights: 100%|█| 196/196 [00:00<00:00, 1521.68it/s, Materializing param=
# Loading weights: 100%|█| 196/196 [00:00<00:00, 1411.86it/s, Materializing param=
# CLIPTextModel LOAD REPORT from: stable-diffusion-v1-5/stable-diffusion-v1-5
# Key                                | Status     |  |
# -----------------------------------+------------+--+-
# text_model.embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/stable-diffusion-v1-5/stable-diffusion-v1-5/resolve/main/vae/config.json "HTTP/1.1 307 Temporary Redirect"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/stable-diffusion-v1-5/stable-diffusion-v1-5/451f4fe16113bff5a5d2269ed5ad43b0592e9a14/vae%2Fconfig.json "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://huggingface.co/api/resolve-cache/models/stable-diffusion-v1-5/stable-diffusion-v1-5/451f4fe16113bff5a5d2269ed5ad43b0592e9a14/vae%2Fconfig.json "HTTP/1.1 200 OK"
# config.json: 100%|█████████████████████████████| 547/547 [00:00<00:00, 3.13MB/s]
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/stable-diffusion-v1-5/stable-diffusion-v1-5/resolve/main/vae/config.json "HTTP/1.1 307 Temporary Redirect"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/stable-diffusion-v1-5/stable-diffusion-v1-5/451f4fe16113bff5a5d2269ed5ad43b0592e9a14/vae%2Fconfig.json "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/stable-diffusion-v1-5/stable-diffusion-v1-5/resolve/451f4fe16113bff5a5d2269ed5ad43b0592e9a14/vae/diffusion_pytorch_model.safetensors.index.json "HTTP/1.1 404 Not Found"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/stable-diffusion-v1-5/stable-diffusion-v1-5/resolve/451f4fe16113bff5a5d2269ed5ad43b0592e9a14/vae/diffusion_pytorch_model.safetensors.index.json "HTTP/1.1 404 Not Found"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/stable-diffusion-v1-5/stable-diffusion-v1-5/resolve/451f4fe16113bff5a5d2269ed5ad43b0592e9a14/vae/diffusion_pytorch_model.safetensors "HTTP/1.1 302 Found"
# vae/diffusion_pytorch_model.safetensors:   0%|       | 0.00/335M [00:00<?, ?B/s]INFO:httpx:HTTP Request: HEAD https://huggingface.co/stable-diffusion-v1-5/stable-diffusion-v1-5/resolve/451f4fe16113bff5a5d2269ed5ad43b0592e9a14/vae/diffusion_pytorch_model.safetensors "HTTP/1.1 302 Found"
# vae/diffusion_pytorch_model.safetensors: 100%|█| 335M/335M [00:01<00:00, 169MB/s
# {'mid_block_add_attention', 'use_post_quant_conv', 'scaling_factor', 'latents_mean', 'latents_std', 'force_upcast', 'shift_factor', 'use_quant_conv'} was not found in config. Values will be initialized to default values.
# All model checkpoint weights were used when initializing AutoencoderKL.
#
# All the weights of AutoencoderKL were initialized from the model checkpoint at stable-diffusion-v1-5/stable-diffusion-v1-5.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use AutoencoderKL for predictions without further training.
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/stable-diffusion-v1-5/stable-diffusion-v1-5/resolve/main/unet/config.json "HTTP/1.1 307 Temporary Redirect"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/stable-diffusion-v1-5/stable-diffusion-v1-5/resolve/main/unet/config.json "HTTP/1.1 307 Temporary Redirect"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/stable-diffusion-v1-5/stable-diffusion-v1-5/451f4fe16113bff5a5d2269ed5ad43b0592e9a14/unet%2Fconfig.json "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://huggingface.co/api/resolve-cache/models/stable-diffusion-v1-5/stable-diffusion-v1-5/451f4fe16113bff5a5d2269ed5ad43b0592e9a14/unet%2Fconfig.json "HTTP/1.1 200 OK"
# config.json: 100%|█████████████████████████████| 743/743 [00:00<00:00, 3.74MB/s]
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/stable-diffusion-v1-5/stable-diffusion-v1-5/451f4fe16113bff5a5d2269ed5ad43b0592e9a14/unet%2Fconfig.json "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/stable-diffusion-v1-5/stable-diffusion-v1-5/resolve/451f4fe16113bff5a5d2269ed5ad43b0592e9a14/unet/diffusion_pytorch_model.safetensors.index.json "HTTP/1.1 404 Not Found"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/stable-diffusion-v1-5/stable-diffusion-v1-5/resolve/451f4fe16113bff5a5d2269ed5ad43b0592e9a14/unet/diffusion_pytorch_model.safetensors.index.json "HTTP/1.1 404 Not Found"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/stable-diffusion-v1-5/stable-diffusion-v1-5/resolve/451f4fe16113bff5a5d2269ed5ad43b0592e9a14/unet/diffusion_pytorch_model.safetensors "HTTP/1.1 302 Found"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/stable-diffusion-v1-5/stable-diffusion-v1-5/resolve/451f4fe16113bff5a5d2269ed5ad43b0592e9a14/unet/diffusion_pytorch_model.safetensors "HTTP/1.1 302 Found"
# INFO:httpx:HTTP Request: GET https://huggingface.co/api/models/stable-diffusion-v1-5/stable-diffusion-v1-5/xet-read-token/451f4fe16113bff5a5d2269ed5ad43b0592e9a14 "HTTP/1.1 200 OK"
# unet/diffusion_pytorch_model.safetensors:  62%|▌| 2.15G/3.44G [00:13<00:08, 158M
# {'addition_time_embed_dim', 'use_linear_projection', 'timestep_post_act', 'attention_type', 'conv_in_kernel', 'cross_attention_norm', 'projection_class_embeddings_input_dim', 'addition_embed_type_num_heads', 'num_attention_heads', 'only_cross_attention', 'class_embed_type', 'encoder_hid_dim', 'upcast_attention', 'addition_embed_type', 'dropout', 'time_embedding_act_fn', 'dual_cross_attention', 'time_embedding_dim', 'class_embeddings_concat', 'time_embedding_type', 'mid_block_type', 'resnet_skip_time_act', 'resnet_time_scale_shift', 'encoder_hid_dim_type', 'time_cond_proj_dim', 'resnet_out_scale_factor', 'mid_block_only_cross_attention', 'conv_out_kernel', 'reverse_transformer_layers_per_block', 'transformer_layers_per_block', 'num_class_embeds'} was not found in config. Values will be initialized to default values.
# All model checkpoint weights were used when initializing UNet2DConditionModel.
#
# All the weights of UNet2DConditionModel were initialized from the model checkpoint at stable-diffusion-v1-5/stable-diffusion-v1-5.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use UNet2DConditionModel for predictions without further training.
# INFO:httpx:HTTP Request: HEAD https://s3.amazonaws.com/datasets.huggingface.co/datasets/datasets/imagefolder/imagefolder.py "HTTP/1.1 404 Not Found"
# Generating train split: 0 examples [00:00, ? examples/s]INFO:httpx:HTTP Request: HEAD https://s3.amazonaws.com/datasets.huggingface.co/datasets/datasets/imagefolder/imagefolder.py "HTTP/1.1 404 Not Found"
# Generating train split: 5000 examples [00:00, 31819.82 examples/s]
# 2026-04-25 12:12:44.599157: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1777119164.811205      74 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1777119164.873914      74 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1777119165.393454      74 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1777119165.393498      74 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1777119165.393504      74 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1777119165.393510      74 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# INFO:__main__:***** Running training *****
# INFO:__main__:  Num examples = 5000
# INFO:__main__:  Num Epochs = 8
# INFO:__main__:  Instantaneous batch size per device = 1
# INFO:__main__:  Total train batch size (w. parallel, distributed & accumulation) = 8
# INFO:__main__:  Gradient Accumulation steps = 4
# INFO:__main__:  Total optimization steps = 5000
# Steps:   8%| | 400/5000 [14:31<2:49:31,  2.21s/it, lr=9.96e-5, step_loss=0.0215]INFO:accelerate.accelerator:Saving current state to /kaggle/working/cityscapes-lora325000/checkpoint-400
# Model weights saved in /kaggle/working/cityscapes-lora325000/checkpoint-400/pytorch_lora_weights.safetensors
# INFO:accelerate.checkpointing:Optimizer state saved in /kaggle/working/cityscapes-lora325000/checkpoint-400/optimizer.bin
# INFO:accelerate.checkpointing:Scheduler state saved in /kaggle/working/cityscapes-lora325000/checkpoint-400/scheduler.bin
# INFO:accelerate.checkpointing:Sampler state for dataloader 0 saved in /kaggle/working/cityscapes-lora325000/checkpoint-400/sampler.bin
# INFO:accelerate.checkpointing:Gradient scaler state saved in /kaggle/working/cityscapes-lora325000/checkpoint-400/scaler.pt
# INFO:accelerate.checkpointing:Random states saved in /kaggle/working/cityscapes-lora325000/checkpoint-400/random_states_0.pkl
# INFO:__main__:Saved state to /kaggle/working/cityscapes-lora325000/checkpoint-400
# Steps:  16%|▎ | 800/5000 [28:41<2:22:42,  2.04s/it, lr=9.62e-5, step_loss=0.199]INFO:accelerate.accelerator:Saving current state to /kaggle/working/cityscapes-lora325000/checkpoint-800
# Model weights saved in /kaggle/working/cityscapes-lora325000/checkpoint-800/pytorch_lora_weights.safetensors
# INFO:accelerate.checkpointing:Optimizer state saved in /kaggle/working/cityscapes-lora325000/checkpoint-800/optimizer.bin
# INFO:accelerate.checkpointing:Scheduler state saved in /kaggle/working/cityscapes-lora325000/checkpoint-800/scheduler.bin
# INFO:accelerate.checkpointing:Sampler state for dataloader 0 saved in /kaggle/working/cityscapes-lora325000/checkpoint-800/sampler.bin
# INFO:accelerate.checkpointing:Gradient scaler state saved in /kaggle/working/cityscapes-lora325000/checkpoint-800/scaler.pt
# INFO:accelerate.checkpointing:Random states saved in /kaggle/working/cityscapes-lora325000/checkpoint-800/random_states_0.pkl
# INFO:__main__:Saved state to /kaggle/working/cityscapes-lora325000/checkpoint-800
# Steps:  24%|▍ | 1200/5000 [42:11<2:08:42,  2.03s/it, lr=8.97e-5, step_loss=0.27]INFO:accelerate.accelerator:Saving current state to /kaggle/working/cityscapes-lora325000/checkpoint-1200
# Model weights saved in /kaggle/working/cityscapes-lora325000/checkpoint-1200/pytorch_lora_weights.safetensors
# INFO:accelerate.checkpointing:Optimizer state saved in /kaggle/working/cityscapes-lora325000/checkpoint-1200/optimizer.bin
# INFO:accelerate.checkpointing:Scheduler state saved in /kaggle/working/cityscapes-lora325000/checkpoint-1200/scheduler.bin
# INFO:accelerate.checkpointing:Sampler state for dataloader 0 saved in /kaggle/working/cityscapes-lora325000/checkpoint-1200/sampler.bin
# INFO:accelerate.checkpointing:Gradient scaler state saved in /kaggle/working/cityscapes-lora325000/checkpoint-1200/scaler.pt
# INFO:accelerate.checkpointing:Random states saved in /kaggle/working/cityscapes-lora325000/checkpoint-1200/random_states_0.pkl
# INFO:__main__:Saved state to /kaggle/working/cityscapes-lora325000/checkpoint-1200
# Steps:  32%|▎| 1600/5000 [55:52<1:54:23,  2.02s/it, lr=8.05e-5, step_loss=0.0097INFO:accelerate.accelerator:Saving current state to /kaggle/working/cityscapes-lora325000/checkpoint-1600
# Model weights saved in /kaggle/working/cityscapes-lora325000/checkpoint-1600/pytorch_lora_weights.safetensors
# INFO:accelerate.checkpointing:Optimizer state saved in /kaggle/working/cityscapes-lora325000/checkpoint-1600/optimizer.bin
# INFO:accelerate.checkpointing:Scheduler state saved in /kaggle/working/cityscapes-lora325000/checkpoint-1600/scheduler.bin
# INFO:accelerate.checkpointing:Sampler state for dataloader 0 saved in /kaggle/working/cityscapes-lora325000/checkpoint-1600/sampler.bin
# INFO:accelerate.checkpointing:Gradient scaler state saved in /kaggle/working/cityscapes-lora325000/checkpoint-1600/scaler.pt
# INFO:accelerate.checkpointing:Random states saved in /kaggle/working/cityscapes-lora325000/checkpoint-1600/random_states_0.pkl
# INFO:__main__:Saved state to /kaggle/working/cityscapes-lora325000/checkpoint-1600
# Steps:  40%|▍| 2000/5000 [1:09:22<1:41:28,  2.03s/it, lr=6.92e-5, step_loss=0.2]INFO:accelerate.accelerator:Saving current state to /kaggle/working/cityscapes-lora325000/checkpoint-2000
# Model weights saved in /kaggle/working/cityscapes-lora325000/checkpoint-2000/pytorch_lora_weights.safetensors
# INFO:accelerate.checkpointing:Optimizer state saved in /kaggle/working/cityscapes-lora325000/checkpoint-2000/optimizer.bin
# INFO:accelerate.checkpointing:Scheduler state saved in /kaggle/working/cityscapes-lora325000/checkpoint-2000/scheduler.bin
# INFO:accelerate.checkpointing:Sampler state for dataloader 0 saved in /kaggle/working/cityscapes-lora325000/checkpoint-2000/sampler.bin
# INFO:accelerate.checkpointing:Gradient scaler state saved in /kaggle/working/cityscapes-lora325000/checkpoint-2000/scaler.pt
# INFO:accelerate.checkpointing:Random states saved in /kaggle/working/cityscapes-lora325000/checkpoint-2000/random_states_0.pkl
# INFO:__main__:Saved state to /kaggle/working/cityscapes-lora325000/checkpoint-2000
# Steps:  48%|▍| 2400/5000 [1:23:00<1:28:40,  2.05s/it, lr=5.66e-5, step_loss=0.11INFO:accelerate.accelerator:Saving current state to /kaggle/working/cityscapes-lora325000/checkpoint-2400
# Model weights saved in /kaggle/working/cityscapes-lora325000/checkpoint-2400/pytorch_lora_weights.safetensors
# INFO:accelerate.checkpointing:Optimizer state saved in /kaggle/working/cityscapes-lora325000/checkpoint-2400/optimizer.bin
# INFO:accelerate.checkpointing:Scheduler state saved in /kaggle/working/cityscapes-lora325000/checkpoint-2400/scheduler.bin
# INFO:accelerate.checkpointing:Sampler state for dataloader 0 saved in /kaggle/working/cityscapes-lora325000/checkpoint-2400/sampler.bin
# INFO:accelerate.checkpointing:Gradient scaler state saved in /kaggle/working/cityscapes-lora325000/checkpoint-2400/scaler.pt
# INFO:accelerate.checkpointing:Random states saved in /kaggle/working/cityscapes-lora325000/checkpoint-2400/random_states_0.pkl
# INFO:__main__:Saved state to /kaggle/working/cityscapes-lora325000/checkpoint-2400
# Steps:  56%|▌| 2800/5000 [1:36:40<1:14:56,  2.04s/it, lr=4.35e-5, step_loss=0.30INFO:accelerate.accelerator:Saving current state to /kaggle/working/cityscapes-lora325000/checkpoint-2800
# Model weights saved in /kaggle/working/cityscapes-lora325000/checkpoint-2800/pytorch_lora_weights.safetensors
# INFO:accelerate.checkpointing:Optimizer state saved in /kaggle/working/cityscapes-lora325000/checkpoint-2800/optimizer.bin
# INFO:accelerate.checkpointing:Scheduler state saved in /kaggle/working/cityscapes-lora325000/checkpoint-2800/scheduler.bin
# INFO:accelerate.checkpointing:Sampler state for dataloader 0 saved in /kaggle/working/cityscapes-lora325000/checkpoint-2800/sampler.bin
# INFO:accelerate.checkpointing:Gradient scaler state saved in /kaggle/working/cityscapes-lora325000/checkpoint-2800/scaler.pt
# INFO:accelerate.checkpointing:Random states saved in /kaggle/working/cityscapes-lora325000/checkpoint-2800/random_states_0.pkl
# INFO:__main__:Saved state to /kaggle/working/cityscapes-lora325000/checkpoint-2800
# Steps:  64%|▋| 3200/5000 [1:50:26<1:02:34,  2.09s/it, lr=3.09e-5, step_loss=0.08INFO:accelerate.accelerator:Saving current state to /kaggle/working/cityscapes-lora325000/checkpoint-3200
# Model weights saved in /kaggle/working/cityscapes-lora325000/checkpoint-3200/pytorch_lora_weights.safetensors
# INFO:accelerate.checkpointing:Optimizer state saved in /kaggle/working/cityscapes-lora325000/checkpoint-3200/optimizer.bin
# INFO:accelerate.checkpointing:Scheduler state saved in /kaggle/working/cityscapes-lora325000/checkpoint-3200/scheduler.bin
# INFO:accelerate.checkpointing:Sampler state for dataloader 0 saved in /kaggle/working/cityscapes-lora325000/checkpoint-3200/sampler.bin
# INFO:accelerate.checkpointing:Gradient scaler state saved in /kaggle/working/cityscapes-lora325000/checkpoint-3200/scaler.pt
# INFO:accelerate.checkpointing:Random states saved in /kaggle/working/cityscapes-lora325000/checkpoint-3200/random_states_0.pkl
# INFO:__main__:Saved state to /kaggle/working/cityscapes-lora325000/checkpoint-3200
# Steps:  72%|▋| 3600/5000 [2:04:04<47:47,  2.05s/it, lr=1.96e-5, step_loss=0.0036INFO:accelerate.accelerator:Saving current state to /kaggle/working/cityscapes-lora325000/checkpoint-3600
# Model weights saved in /kaggle/working/cityscapes-lora325000/checkpoint-3600/pytorch_lora_weights.safetensors
# INFO:accelerate.checkpointing:Optimizer state saved in /kaggle/working/cityscapes-lora325000/checkpoint-3600/optimizer.bin
# INFO:accelerate.checkpointing:Scheduler state saved in /kaggle/working/cityscapes-lora325000/checkpoint-3600/scheduler.bin
# INFO:accelerate.checkpointing:Sampler state for dataloader 0 saved in /kaggle/working/cityscapes-lora325000/checkpoint-3600/sampler.bin
# INFO:accelerate.checkpointing:Gradient scaler state saved in /kaggle/working/cityscapes-lora325000/checkpoint-3600/scaler.pt
# INFO:accelerate.checkpointing:Random states saved in /kaggle/working/cityscapes-lora325000/checkpoint-3600/random_states_0.pkl
# INFO:__main__:Saved state to /kaggle/working/cityscapes-lora325000/checkpoint-3600
# Steps:  80%|▊| 4000/5000 [2:17:43<34:17,  2.06s/it, lr=1.04e-5, step_loss=0.0038INFO:accelerate.accelerator:Saving current state to /kaggle/working/cityscapes-lora325000/checkpoint-4000
# Model weights saved in /kaggle/working/cityscapes-lora325000/checkpoint-4000/pytorch_lora_weights.safetensors
# INFO:accelerate.checkpointing:Optimizer state saved in /kaggle/working/cityscapes-lora325000/checkpoint-4000/optimizer.bin
# INFO:accelerate.checkpointing:Scheduler state saved in /kaggle/working/cityscapes-lora325000/checkpoint-4000/scheduler.bin
# INFO:accelerate.checkpointing:Sampler state for dataloader 0 saved in /kaggle/working/cityscapes-lora325000/checkpoint-4000/sampler.bin
# INFO:accelerate.checkpointing:Gradient scaler state saved in /kaggle/working/cityscapes-lora325000/checkpoint-4000/scaler.pt
# INFO:accelerate.checkpointing:Random states saved in /kaggle/working/cityscapes-lora325000/checkpoint-4000/random_states_0.pkl
# INFO:__main__:Saved state to /kaggle/working/cityscapes-lora325000/checkpoint-4000
# Steps:  88%|▉| 4400/5000 [2:31:23<20:32,  2.05s/it, lr=3.82e-6, step_loss=0.0027INFO:accelerate.accelerator:Saving current state to /kaggle/working/cityscapes-lora325000/checkpoint-4400
# Model weights saved in /kaggle/working/cityscapes-lora325000/checkpoint-4400/pytorch_lora_weights.safetensors
# INFO:accelerate.checkpointing:Optimizer state saved in /kaggle/working/cityscapes-lora325000/checkpoint-4400/optimizer.bin
# INFO:accelerate.checkpointing:Scheduler state saved in /kaggle/working/cityscapes-lora325000/checkpoint-4400/scheduler.bin
# INFO:accelerate.checkpointing:Sampler state for dataloader 0 saved in /kaggle/working/cityscapes-lora325000/checkpoint-4400/sampler.bin
# INFO:accelerate.checkpointing:Gradient scaler state saved in /kaggle/working/cityscapes-lora325000/checkpoint-4400/scaler.pt
# INFO:accelerate.checkpointing:Random states saved in /kaggle/working/cityscapes-lora325000/checkpoint-4400/random_states_0.pkl
# INFO:__main__:Saved state to /kaggle/working/cityscapes-lora325000/checkpoint-4400
# Steps:  96%|▉| 4800/5000 [2:45:05<06:59,  2.10s/it, lr=4.32e-7, step_loss=0.0238INFO:accelerate.accelerator:Saving current state to /kaggle/working/cityscapes-lora325000/checkpoint-4800
# Model weights saved in /kaggle/working/cityscapes-lora325000/checkpoint-4800/pytorch_lora_weights.safetensors
# INFO:accelerate.checkpointing:Optimizer state saved in /kaggle/working/cityscapes-lora325000/checkpoint-4800/optimizer.bin
# INFO:accelerate.checkpointing:Scheduler state saved in /kaggle/working/cityscapes-lora325000/checkpoint-4800/scheduler.bin
# INFO:accelerate.checkpointing:Sampler state for dataloader 0 saved in /kaggle/working/cityscapes-lora325000/checkpoint-4800/sampler.bin
# INFO:accelerate.checkpointing:Gradient scaler state saved in /kaggle/working/cityscapes-lora325000/checkpoint-4800/scaler.pt
# INFO:accelerate.checkpointing:Random states saved in /kaggle/working/cityscapes-lora325000/checkpoint-4800/random_states_0.pkl
# INFO:__main__:Saved state to /kaggle/working/cityscapes-lora325000/checkpoint-4800
# Steps: 100%|██████| 5000/5000 [2:52:03<00:00,  2.02s/it, lr=0, step_loss=0.0108]Model weights saved in /kaggle/working/cityscapes-lora325000/pytorch_lora_weights.safetensors
# Steps: 100%|██████| 5000/5000 [2:52:04<00:00,  2.06s/it, lr=0, step_loss=0.0108]

# %%
# Check the output files
import os

print("=== Output files ===")
for root, dirs, files in os.walk("/kaggle/working/cityscapes-lora325000"):
    for f in files:
        full = os.path.join(root, f)
        size = os.path.getsize(full) / 1e6
        rel = os.path.relpath(full, "/kaggle/working/cityscapes-lora325000")
        print(f"  {size:8.2f} MB  {rel}")
# Out:
# === Output files ===
#      25.55 MB  pytorch_lora_weights.safetensors
#       0.02 MB  checkpoint-2000/random_states_0.pkl
#       0.00 MB  checkpoint-2000/scheduler.bin
#       0.00 MB  checkpoint-2000/scaler.pt
#      51.23 MB  checkpoint-2000/optimizer.bin
#      25.55 MB  checkpoint-2000/pytorch_lora_weights.safetensors
#       0.02 MB  checkpoint-1600/random_states_0.pkl
#       0.00 MB  checkpoint-1600/scheduler.bin
#       0.00 MB  checkpoint-1600/scaler.pt
#      51.23 MB  checkpoint-1600/optimizer.bin
#      25.55 MB  checkpoint-1600/pytorch_lora_weights.safetensors
#       0.02 MB  checkpoint-2400/random_states_0.pkl
#       0.00 MB  checkpoint-2400/scheduler.bin
#       0.00 MB  checkpoint-2400/scaler.pt
#      51.23 MB  checkpoint-2400/optimizer.bin
#      25.55 MB  checkpoint-2400/pytorch_lora_weights.safetensors
#       0.02 MB  checkpoint-3200/random_states_0.pkl
#       0.00 MB  checkpoint-3200/scheduler.bin
#       0.00 MB  checkpoint-3200/scaler.pt
#      51.23 MB  checkpoint-3200/optimizer.bin
#      25.55 MB  checkpoint-3200/pytorch_lora_weights.safetensors
#       0.02 MB  checkpoint-2800/random_states_0.pkl
#       0.00 MB  checkpoint-2800/scheduler.bin
#       0.00 MB  checkpoint-2800/scaler.pt
#      51.23 MB  checkpoint-2800/optimizer.bin
#      25.55 MB  checkpoint-2800/pytorch_lora_weights.safetensors
#       0.02 MB  checkpoint-4800/random_states_0.pkl
#       0.00 MB  checkpoint-4800/scheduler.bin
#       0.00 MB  checkpoint-4800/scaler.pt
#      51.23 MB  checkpoint-4800/optimizer.bin
#      25.55 MB  checkpoint-4800/pytorch_lora_weights.safetensors
#       0.02 MB  checkpoint-4400/random_states_0.pkl
#       0.00 MB  checkpoint-4400/scheduler.bin
#       0.00 MB  checkpoint-4400/scaler.pt
#      51.23 MB  checkpoint-4400/optimizer.bin
#      25.55 MB  checkpoint-4400/pytorch_lora_weights.safetensors
#       0.02 MB  checkpoint-1200/random_states_0.pkl
#       0.00 MB  checkpoint-1200/scheduler.bin
#       0.00 MB  checkpoint-1200/scaler.pt
#      51.23 MB  checkpoint-1200/optimizer.bin
#      25.55 MB  checkpoint-1200/pytorch_lora_weights.safetensors
#       0.02 MB  checkpoint-400/random_states_0.pkl
#       0.00 MB  checkpoint-400/scheduler.bin
#       0.00 MB  checkpoint-400/scaler.pt
#      51.23 MB  checkpoint-400/optimizer.bin
#      25.55 MB  checkpoint-400/pytorch_lora_weights.safetensors
#       0.02 MB  checkpoint-3600/random_states_0.pkl
#       0.00 MB  checkpoint-3600/scheduler.bin
#       0.00 MB  checkpoint-3600/scaler.pt
#      51.23 MB  checkpoint-3600/optimizer.bin
#      25.55 MB  checkpoint-3600/pytorch_lora_weights.safetensors
#       0.02 MB  checkpoint-800/random_states_0.pkl
#       0.00 MB  checkpoint-800/scheduler.bin
#       0.00 MB  checkpoint-800/scaler.pt
#      51.23 MB  checkpoint-800/optimizer.bin
#      25.55 MB  checkpoint-800/pytorch_lora_weights.safetensors
#       0.02 MB  checkpoint-4000/random_states_0.pkl
#       0.00 MB  checkpoint-4000/scheduler.bin
#       0.00 MB  checkpoint-4000/scaler.pt
#      51.23 MB  checkpoint-4000/optimizer.bin
#      25.55 MB  checkpoint-4000/pytorch_lora_weights.safetensors

# %%
# from diffusers import StableDiffusionPipeline
# import torch

# SD_PATH = "/kaggle/input/datasets/narmeensabahsiddiqui/sd15-diffusers"
# LORA_PATH = "/kaggle/working/cityscapes-lora-pilot"

# prompt = "A dashcam view of a European city street with cars, buildings, and pedestrians"

# # Load without safety checker (which needs the missing feature_extractor)
# pipe = StableDiffusionPipeline.from_pretrained(
#     SD_PATH, 
#     torch_dtype=torch.float16,
#     safety_checker=None,
#     feature_extractor=None
# ).to("cuda")

# # Generate with frozen SD 1.5
# generator = torch.Generator("cuda").manual_seed(42)
# img_frozen = pipe(prompt, generator=generator, num_inference_steps=30).images[0]

# # Load LoRA weights and generate again
# pipe.load_lora_weights(LORA_PATH)
# generator = torch.Generator("cuda").manual_seed(42)
# img_lora = pipe(prompt, generator=generator, num_inference_steps=30).images[0]

# # Display side by side
# import matplotlib.pyplot as plt
# fig, axes = plt.subplots(1, 2, figsize=(14, 6))
# axes[0].imshow(img_frozen)
# axes[0].set_title("Frozen SD 1.5", fontsize=13)
# axes[0].axis("off")
# axes[1].imshow(img_lora)
# axes[1].set_title("LoRA-adapted SD 1.5 (200 steps)", fontsize=13)
# axes[1].axis("off")
# plt.suptitle(f'Prompt: "{prompt}"', fontsize=11, y=0.02)
# plt.tight_layout()
# plt.show()
from diffusers import StableDiffusionPipeline
import torch
import matplotlib.pyplot as plt

# SD_PATH = "/kaggle/input/datasets/narmeensabahsiddiqui/sd15-diffusers"
LORA_PATH = "/kaggle/working/cityscapes-lora325000" #changed from  "/kaggle/working/cityscapes-lora-pilot"

prompts = [
    "A dashcam view of a European city street with cars, buildings, and pedestrians",
    "A narrow street with parked cars and trees on both sides under overcast sky",
    "A busy intersection with traffic lights, buses, and cyclists in a city",
]

# Load pipeline without safety checker
pipe = StableDiffusionPipeline.from_pretrained(
    "stable-diffusion-v1-5/stable-diffusion-v1-5", torch_dtype=torch.float16,
    safety_checker=None, feature_extractor=None
).to("cuda")

fig, axes = plt.subplots(len(prompts), 2, figsize=(14, 6 * len(prompts)))

for i, prompt in enumerate(prompts):
    # Frozen SD 1.5
    pipe.unload_lora_weights()
    generator = torch.Generator("cuda").manual_seed(42 + i)
    img_frozen = pipe(prompt, generator=generator, num_inference_steps=30).images[0]
    
    # LoRA-adapted
    pipe.load_lora_weights(LORA_PATH)
    generator = torch.Generator("cuda").manual_seed(42 + i)
    img_lora = pipe(prompt, generator=generator, num_inference_steps=30).images[0]
    
    axes[i, 0].imshow(img_frozen)
    axes[i, 0].set_title("Frozen SD 1.5" if i == 0 else "", fontsize=13)
    axes[i, 0].set_ylabel(prompt[:50] + "...", fontsize=9, rotation=0, labelpad=120, va='center')
    axes[i, 0].axis("off")
    
    axes[i, 1].imshow(img_lora)
    axes[i, 1].set_title("LoRA-adapted (32 Rank 5000 steps)" if i == 0 else "", fontsize=13)
    axes[i, 1].axis("off")

plt.tight_layout()
plt.show()
# Out:
# Flax classes are deprecated and will be removed in Diffusers v1.0.0. We recommend migrating to PyTorch classes or pinning your version of Diffusers.
# Flax classes are deprecated and will be removed in Diffusers v1.0.0. We recommend migrating to PyTorch classes or pinning your version of Diffusers.
# model_index.json:   0%|          | 0.00/541 [00:00<?, ?B/s]
# Loading pipeline components...:   0%|          | 0/5 [00:00<?, ?it/s]
# Loading weights:   0%|          | 0/196 [00:00<?, ?it/s]
# CLIPTextModel LOAD REPORT from: /root/.cache/huggingface/hub/models--stable-diffusion-v1-5--stable-diffusion-v1-5/snapshots/451f4fe16113bff5a5d2269ed5ad43b0592e9a14/text_encoder
# Key                                | Status     |  |
# -----------------------------------+------------+--+-
# text_model.embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# You have disabled the safety checker for <class 'diffusers.pipelines.stable_diffusion.pipeline_stable_diffusion.StableDiffusionPipeline'> by passing `safety_checker=None`. Ensure that you abide to the conditions of the Stable Diffusion license and do not expose unfiltered results in services or applications open to the public. Both the diffusers team and Hugging Face strongly recommend to keep the safety filter enabled in all public facing circumstances, disabling it only for use-cases that involve analyzing network behavior or auditing its results. For more information, please have a look at https://github.com/huggingface/diffusers/pull/254 .
#   0%|          | 0/30 [00:00<?, ?it/s]
# No LoRA keys associated to CLIPTextModel found with the prefix='text_encoder'. This is safe to ignore if LoRA state dict didn't originally have any CLIPTextModel related params. You can also try specifying `prefix=None` to resolve the warning. Otherwise, open an issue if you think it's unexpected: https://github.com/huggingface/diffusers/issues/new
#   0%|          | 0/30 [00:00<?, ?it/s]
#   0%|          | 0/30 [00:00<?, ?it/s]
# No LoRA keys associated to CLIPTextModel found with the prefix='text_encoder'. This is safe to ignore if LoRA state dict didn't originally have any CLIPTextModel related params. You can also try specifying `prefix=None` to resolve the warning. Otherwise, open an issue if you think it's unexpected: https://github.com/huggingface/diffusers/issues/new
#   0%|          | 0/30 [00:00<?, ?it/s]
#   0%|          | 0/30 [00:00<?, ?it/s]
# No LoRA keys associated to CLIPTextModel found with the prefix='text_encoder'. This is safe to ignore if LoRA state dict didn't originally have any CLIPTextModel related params. You can also try specifying `prefix=None` to resolve the warning. Otherwise, open an issue if you think it's unexpected: https://github.com/huggingface/diffusers/issues/new
#   0%|          | 0/30 [00:00<?, ?it/s]
